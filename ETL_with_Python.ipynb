# %% [markdown]
# ## Web Scraping

# %%
import pandas as pd
import logging #untuk menampilkan log di terminal

logging.basicConfig(level=logging.INFO)

# %%
url =  "https://id.wikipedia.org/wiki/Daftar_orang_terkaya_di_Indonesia"

# %%
def scrape(url):
    logging.info(f"Scraping website with url: '{url}' ...")
    return pd.read_html(url, header=None)

    #header = none artinya tidak ada scenario yang dikhususkan, artinya none ini brarti headernya langsung ambil di web

# %%
dfs = scrape(url)[7] #7 adalah index, jadi nanti ngmabil data yang 2020
# Out:
# INFO:root:Scraping website with url: 'https://id.wikipedia.org/wiki/Daftar_orang_terkaya_di_Indonesia' ...

# %%
dfs
# Out:
#     Nomor Urut                                             Nama  \
# 0            1  Robert Budi Hartono dan Michael Bambang Hartono
# 1            2                                   Widjaja family
# 2            3                                 Prajogo Pangestu
# 3            4                                    Anthony Salim
# 4            5                                Sri Prakash Lohia
# 5            6                               Susilo Wonowidjojo
# 6            7                              Jogi Hendra Atmadja
# 7            8                               Boenjamin Setiawan
# 8            9                                  Chairul Tanjung
# 9           10                                            Tahir
# 10          11                                   Bachtiar Karim
# 11          12                                   Martua Sitorus
# 12          13                                 Putera Sampoerna
# 13          14                                   Kuncoro Wibowo
# 14          15                                 Garibaldi Thohir
# 15          16                         Theodore Permadi Rachmat
# 16          17                                    Irwan Hidayat
# 17          18                                    Peter Sondakh
# 18          19                                    Djoko Susanto
# 19          20                        Eddy Kusnadi Sariaatmadja
# 20          21                                    Mochtar Riady
# 21          22                                   Sukanto Tanoto
# 22          23                               Husain Djojonegoro
# 23          24                                   Ciputra family
# 24          25                                   Low Tuck Kwong
# 25          26                              Husodo Angkosubroto
# 26          27                                  Alexander Tedja
# 27          28                                 Winarko Sulistyo
# 28          29                                      Murdaya Poo
# 29          30                               Ciliandra Fangiono
# 30          31                             Eddy William Katuari
# 31          32                     Lim Hariyanto Wijaya Sarwono
# 32          33                               Hary Tanoesoedibjo
# 33          34                            Sabana Prawirawidjaja
# 34          35                                 Sjamsul Nursalim
# 35          36                                     Osbert Lyman
# 36          37                                    Hamami family
# 37          38                                  Handojo Santosa
# 38          39                  Wijono Tanoko & Hermanto Tanoko
# 39          40                           Hashim Djojohadikusumo
# 40          41                                         Sudhamek
# 41          42                                  Kartini Muljadi
# 42          43                         Arini Saraswati Subianto
# 43          44                                         Jerry Ng
# 44          45                                Edwin Soeryadjaya
# 45          46                            Soegiarto Adikoesoemo
# 46          47                                  Arifin Panigoro
# 47          48                                    Harjo Sutanto
# 48          49                                    Iwan Lukminto
# 49          50                                  Susanto Suwarto
#
#                    Perusahaan Kekayaan Bersih (US$)
# 0                      Djarum           38.8 miliar
# 1             Sinar Mas Group           11.9 miliar
# 2              Barito Pacific              6 miliar
# 3                 Salim Group            5.9 miliar
# 4        Indorama Corporation            5,6 miliar
# 5                Gudang Garam            5.3 miliar
# 6                Mayora Indah            4.3 miliar
# 7                 Kalbe Farma            4.1 miliar
# 8                     CT Corp            3.9 miliar
# 9              Mayapada Group            3.3 miliar
# 10                  Musim Mas            3.1 miliar
# 11       Wilmar International              2 miliar
# 12  Sampoerna Strategic Group            1,8 miliar
# 13               Ace Hardware           1.75 miliar
# 14               Adaro Energy           1.65 miliar
# 15             Triputra Group            1.6 miliar
# 16                Sido Muncul           1.55 miliar
# 17           Rajawali Corpora            1.5 miliar
# 18                   Alfamart           1.45 miliar
# 19    Elang Mahkota Teknologi            1.4 miliar
# 20                Lippo Group           1.38 miliar
# 21         Royal Golden Eagle           1.35 miliar
# 22            Orang Tua Group           1.32 miliar
# 23                    Ciputra           1.28 miliar
# 24            Bayan Resources           1.22 miliar
# 25          Gunung Sewu Group            1.2 miliar
# 26               Pakuwon Jati           1.19 miliar
# 27         Fajar Surya Wisesa           1.15 miliar
# 28      Central Cipta Murdaya           1.14 miliar
# 29            First Resources           1.05 miliar
# 30                      Wings              1 miliar
# 31               Harita Group              960 juta
# 32            MNC Corporation              950 juta
# 33                  Ultrajaya              885 juta
# 34              Gajah Tunggal              755 juta
# 35                Lyman Group              750 juta
# 36       Tiara Marga Trakindo              745 juta
# 37    Japfa Comfeed Indonesia              735 juta
# 38                      Avian              700 juta
# 39               Arsari Group              685 juta
# 40                 GarudaFood              635 juta
# 41                 Tempo Scan              620 juta
# 42  Persada Capital Investama              610 juta
# 43                  Bank Jago              600 juta
# 44  Saratoga Investama Sedaya              580 juta
# 45             AKR Corporindo              555 juta
# 46                MedcoEnergi              550 Juta
# 47                      Wings              530 juta
# 48           Sri Rejeki Isman              515 juta
# 49    Elang Mahkota Teknologi              475 juta

# %%
dfs.head()
# Out:
#    Nomor Urut                                             Nama  \
# 0           1  Robert Budi Hartono dan Michael Bambang Hartono
# 1           2                                   Widjaja family
# 2           3                                 Prajogo Pangestu
# 3           4                                    Anthony Salim
# 4           5                                Sri Prakash Lohia
#
#              Perusahaan Kekayaan Bersih (US$)
# 0                Djarum           38.8 miliar
# 1       Sinar Mas Group           11.9 miliar
# 2        Barito Pacific              6 miliar
# 3           Salim Group            5.9 miliar
# 4  Indorama Corporation            5,6 miliar

# %% [markdown]
# ### Practice
# Lakukan Web scraping pandas read_html seperti diatas

# %% [markdown]
# # Cleaning Data

# %%
import re #ini regex

# %%
def is_money_miliar(string_money):
    return string_money.lower().endswith("miliar") #untuk detect yang akhirannya miliar

# %%
def transform_money_format(string_money):
  #mengganti koma jadi titik dan menghilangkan spasi
    half_clean_string = string_money.lower().replace(",", ".").replace(" ", "")
    # mendeteksi string M atau miliar dan J atau juta dan mengganti dengan string kosong
    return re.sub(r"[?\[M\]miliar|\[J\]juta]", "", half_clean_string) #re.sub adalah fungsi untuk search and replace

# %%
#transform dataframe

def transform(df, tahun):
    logging.info("Transforming DataFrame ...")

    columns_mapping = {
        "Nomor Urut": "nomor_urut",
        "Nama": "nama",
        "Perusahaan": "perusahaan",
        "Kekayaan Bersih (US$)": "kekayaan_bersih_usd"
    }

#mengganti nama column sebelumnya sesuai kebutuhan
    renamed_df = df.rename(columns=columns_mapping)

#menambhakan colom tahun dan memberinya value yang berasal dari parameter tahun
    renamed_df["tahun"] = tahun

#memberi nilai pada kekayaan_bersih_usd_juta dgn percabangan if else
#jika kedetect string miliar (is money miliar), maka dikali 1000 dan string "miliar" atau "juta" dihilangkan
#jika tidak maka meghilangkan string "juta" saja
    renamed_df["kekayaan_bersih_usd_juta"] = renamed_df["kekayaan_bersih_usd"].apply(
        lambda value: float(transform_money_format(value)) * 1000 if is_money_miliar(value) else float(transform_money_format(value))
    )

    return renamed_df[["nomor_urut", "tahun", "nama", "perusahaan", "kekayaan_bersih_usd_juta"]]

# %%
df_2020 = transform(dfs, 2020)
# Out:
# INFO:root:Transforming DataFrame ...

# %%
df_2020
# Out:
#     nomor_urut  tahun                                             nama  \
# 0            1   2020  Robert Budi Hartono dan Michael Bambang Hartono
# 1            2   2020                                   Widjaja family
# 2            3   2020                                 Prajogo Pangestu
# 3            4   2020                                    Anthony Salim
# 4            5   2020                                Sri Prakash Lohia
# 5            6   2020                               Susilo Wonowidjojo
# 6            7   2020                              Jogi Hendra Atmadja
# 7            8   2020                               Boenjamin Setiawan
# 8            9   2020                                  Chairul Tanjung
# 9           10   2020                                            Tahir
# 10          11   2020                                   Bachtiar Karim
# 11          12   2020                                   Martua Sitorus
# 12          13   2020                                 Putera Sampoerna
# 13          14   2020                                   Kuncoro Wibowo
# 14          15   2020                                 Garibaldi Thohir
# 15          16   2020                         Theodore Permadi Rachmat
# 16          17   2020                                    Irwan Hidayat
# 17          18   2020                                    Peter Sondakh
# 18          19   2020                                    Djoko Susanto
# 19          20   2020                        Eddy Kusnadi Sariaatmadja
# 20          21   2020                                    Mochtar Riady
# 21          22   2020                                   Sukanto Tanoto
# 22          23   2020                               Husain Djojonegoro
# 23          24   2020                                   Ciputra family
# 24          25   2020                                   Low Tuck Kwong
# 25          26   2020                              Husodo Angkosubroto
# 26          27   2020                                  Alexander Tedja
# 27          28   2020                                 Winarko Sulistyo
# 28          29   2020                                      Murdaya Poo
# 29          30   2020                               Ciliandra Fangiono
# 30          31   2020                             Eddy William Katuari
# 31          32   2020                     Lim Hariyanto Wijaya Sarwono
# 32          33   2020                               Hary Tanoesoedibjo
# 33          34   2020                            Sabana Prawirawidjaja
# 34          35   2020                                 Sjamsul Nursalim
# 35          36   2020                                     Osbert Lyman
# 36          37   2020                                    Hamami family
# 37          38   2020                                  Handojo Santosa
# 38          39   2020                  Wijono Tanoko & Hermanto Tanoko
# 39          40   2020                           Hashim Djojohadikusumo
# 40          41   2020                                         Sudhamek
# 41          42   2020                                  Kartini Muljadi
# 42          43   2020                         Arini Saraswati Subianto
# 43          44   2020                                         Jerry Ng
# 44          45   2020                                Edwin Soeryadjaya
# 45          46   2020                            Soegiarto Adikoesoemo
# 46          47   2020                                  Arifin Panigoro
# 47          48   2020                                    Harjo Sutanto
# 48          49   2020                                    Iwan Lukminto
# 49          50   2020                                  Susanto Suwarto
#
#                    perusahaan  kekayaan_bersih_usd_juta
# 0                      Djarum                   38800.0
# 1             Sinar Mas Group                   11900.0
# 2              Barito Pacific                    6000.0
# 3                 Salim Group                    5900.0
# 4        Indorama Corporation                    5600.0
# 5                Gudang Garam                    5300.0
# 6                Mayora Indah                    4300.0
# 7                 Kalbe Farma                    4100.0
# 8                     CT Corp                    3900.0
# 9              Mayapada Group                    3300.0
# 10                  Musim Mas                    3100.0
# 11       Wilmar International                    2000.0
# 12  Sampoerna Strategic Group                    1800.0
# 13               Ace Hardware                    1750.0
# 14               Adaro Energy                    1650.0
# 15             Triputra Group                    1600.0
# 16                Sido Muncul                    1550.0
# 17           Rajawali Corpora                    1500.0
# 18                   Alfamart                    1450.0
# 19    Elang Mahkota Teknologi                    1400.0
# 20                Lippo Group                    1380.0
# 21         Royal Golden Eagle                    1350.0
# 22            Orang Tua Group                    1320.0
# 23                    Ciputra                    1280.0
# 24            Bayan Resources                    1220.0
# 25          Gunung Sewu Group                    1200.0
# 26               Pakuwon Jati                    1190.0
# 27         Fajar Surya Wisesa                    1150.0
# 28      Central Cipta Murdaya                    1140.0
# 29            First Resources                    1050.0
# 30                      Wings                    1000.0
# 31               Harita Group                     960.0
# 32            MNC Corporation                     950.0
# 33                  Ultrajaya                     885.0
# 34              Gajah Tunggal                     755.0
# 35                Lyman Group                     750.0
# 36       Tiara Marga Trakindo                     745.0
# 37    Japfa Comfeed Indonesia                     735.0
# 38                      Avian                     700.0
# 39               Arsari Group                     685.0
# 40                 GarudaFood                     635.0
# 41                 Tempo Scan                     620.0
# 42  Persada Capital Investama                     610.0
# 43                  Bank Jago                     600.0
# 44  Saratoga Investama Sedaya                     580.0
# 45             AKR Corporindo                     555.0
# 46                MedcoEnergi                     550.0
# 47                      Wings                     530.0
# 48           Sri Rejeki Isman                     515.0
# 49    Elang Mahkota Teknologi                     475.0

# %% [markdown]
# ### Practice
# Lakukan Cleaning Data seperti diatas

# %% [markdown]
# # Storing Data to Database

# %%
pip install psycopg2-binary==2.8.6
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting psycopg2-binary==2.8.6
#   Downloading psycopg2_binary-2.8.6-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 4.3 MB/s
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.8.6

# %%
from sqlalchemy import create_engine

# %%
DB_NAME = "postgres"
DB_USER = "xxxxx"
DB_PASSWORD = "xxxxx"
DB_HOST = "34.xxx.xx.xx"
DB_PORT = "5xxx"
CONNECTION_STRING = f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}" #urutannya harus spt ini
TABLE_NAME = "orang_terkaya_indonesia_shofa"

# %%
CONNECTION_STRING
# Out:
# 'postgresql://user1:user1@34.171.63.89:5432/postgres'

# %%
#menulis dataframe

def write_to_postgres(df, db_name, table_name, connection_string):
    engine = create_engine(connection_string)

    logging.info(f"Writing dataframe to database: '{db_name}', table: '{table_name}' ...")
    df.to_sql(name = table_name, con=engine, if_exists="replace", index=False) #ini untuk insert

# %%
write_to_postgres(df=df_2020, db_name=DB_NAME, table_name=TABLE_NAME, connection_string=CONNECTION_STRING)

#setelah ini maka table akan ke load ke DB, cek di dbeaver
# Out:
# INFO:root:Writing dataframe to database: 'postgres', table: 'orang_terkaya_indonesia_shofa' ...

# %% [markdown]
# ### Practice
# Storing Data ke PostgreSQL seperti diatas

# %% [markdown]
# # Read Data from Database

# %%
def read_from_postgres(db_name, table_name, connection_string):
    engine = create_engine(connection_string)

    logging.info(f"Reading postgres database: '{db_name}', table: '{table_name}' ...")
    return pd.read_sql_table(table_name, con=engine)

# %%
result_df = read_from_postgres(db_name=DB_NAME, table_name=TABLE_NAME, connection_string=CONNECTION_STRING)
# Out:
# INFO:root:Reading postgres database: 'postgres', table: 'orang_terkaya_indonesia_shofa' ...

# %%
print("Daftar Orang Terkaya di Indonesia:")
print(result_df.to_string())

#nanti hasilnya adalah tabel yang sudah di load ke database, ini ngebaca dari DB ya :D
# Out:
# Daftar Orang Terkaya di Indonesia:
#     nomor_urut  tahun                                             nama                 perusahaan  kekayaan_bersih_usd_juta
# 0            1   2020  Robert Budi Hartono dan Michael Bambang Hartono                     Djarum                   38800.0
# 1            2   2020                                   Widjaja family            Sinar Mas Group                   11900.0
# 2            3   2020                                 Prajogo Pangestu             Barito Pacific                    6000.0
# 3            4   2020                                    Anthony Salim                Salim Group                    5900.0
# 4            5   2020                                Sri Prakash Lohia       Indorama Corporation                    5600.0
# 5            6   2020                               Susilo Wonowidjojo               Gudang Garam                    5300.0
# 6            7   2020                              Jogi Hendra Atmadja               Mayora Indah                    4300.0
# 7            8   2020                               Boenjamin Setiawan                Kalbe Farma                    4100.0
# 8            9   2020                                  Chairul Tanjung                    CT Corp                    3900.0
# 9           10   2020                                            Tahir             Mayapada Group                    3300.0
# 10          11   2020                                   Bachtiar Karim                  Musim Mas                    3100.0
# 11          12   2020                                   Martua Sitorus       Wilmar International                    2000.0
# 12          13   2020                                 Putera Sampoerna  Sampoerna Strategic Group                    1800.0
# 13          14   2020                                   Kuncoro Wibowo               Ace Hardware                    1750.0
# 14          15   2020                                 Garibaldi Thohir               Adaro Energy                    1650.0
# 15          16   2020                         Theodore Permadi Rachmat             Triputra Group                    1600.0
# 16          17   2020                                    Irwan Hidayat                Sido Muncul                    1550.0
# 17          18   2020                                    Peter Sondakh           Rajawali Corpora                    1500.0
# 18          19   2020                                    Djoko Susanto                   Alfamart                    1450.0
# 19          20   2020                        Eddy Kusnadi Sariaatmadja    Elang Mahkota Teknologi                    1400.0
# 20          21   2020                                    Mochtar Riady                Lippo Group                    1380.0
# 21          22   2020                                   Sukanto Tanoto         Royal Golden Eagle                    1350.0
# 22          23   2020                               Husain Djojonegoro            Orang Tua Group                    1320.0
# 23          24   2020                                   Ciputra family                    Ciputra                    1280.0
# 24          25   2020                                   Low Tuck Kwong            Bayan Resources                    1220.0
# 25          26   2020                              Husodo Angkosubroto          Gunung Sewu Group                    1200.0
# 26          27   2020                                  Alexander Tedja               Pakuwon Jati                    1190.0
# 27          28   2020                                 Winarko Sulistyo         Fajar Surya Wisesa                    1150.0
# 28          29   2020                                      Murdaya Poo      Central Cipta Murdaya                    1140.0
# 29          30   2020                               Ciliandra Fangiono            First Resources                    1050.0
# 30          31   2020                             Eddy William Katuari                      Wings                    1000.0
# 31          32   2020                     Lim Hariyanto Wijaya Sarwono               Harita Group                     960.0
# 32          33   2020                               Hary Tanoesoedibjo            MNC Corporation                     950.0
# 33          34   2020                            Sabana Prawirawidjaja                  Ultrajaya                     885.0
# 34          35   2020                                 Sjamsul Nursalim              Gajah Tunggal                     755.0
# 35          36   2020                                     Osbert Lyman                Lyman Group                     750.0
# 36          37   2020                                    Hamami family       Tiara Marga Trakindo                     745.0
# 37          38   2020                                  Handojo Santosa    Japfa Comfeed Indonesia                     735.0
# 38          39   2020                  Wijono Tanoko & Hermanto Tanoko                      Avian                     700.0
# 39          40   2020                           Hashim Djojohadikusumo               Arsari Group                     685.0
# 40          41   2020                                         Sudhamek                 GarudaFood                     635.0
# 41          42   2020                                  Kartini Muljadi                 Tempo Scan                     620.0
# 42          43   2020                         Arini Saraswati Subianto  Persada Capital Investama                     610.0
# 43          44   2020                                         Jerry Ng                  Bank Jago                     600.0
# 44          45   2020                                Edwin Soeryadjaya  Saratoga Investama Sedaya                     580.0
# 45          46   2020                            Soegiarto Adikoesoemo             AKR Corporindo                     555.0
# 46          47   2020                                  Arifin Panigoro                MedcoEnergi                     550.0
# 47          48   2020                                    Harjo Sutanto                      Wings                     530.0
# 48          49   2020                                    Iwan Lukminto           Sri Rejeki Isman                     515.0
# 49          50   2020                                  Susanto Suwarto    Elang Mahkota Teknologi                     475.0

# %% [markdown]
# ### Practice
# Read Data dari PostgreSQL seperti diatas

# %% [markdown]
# # Unittest

# %%
import unittest

class TestTransformer(unittest.TestCase):
    def test_is_money_miliar_when_string_money_contains_miliar(self):
        string_money = "35.5 miliar"
        actual = is_money_miliar(string_money)

        self.assertTrue(string_money)
    
    
    def test_is_money_miliar_when_string_money_not_contains_miliar(self):
        string_money = "980 juta"
        actual = is_money_miliar(string_money)

        self.assertFalse(actual)
    
    
    def test_transform_money_format_when_money_is_juta(self):
        string_money = "980 Juta"
        actual = transform_money_format(string_money)

        self.assertEqual(actual, "980")
    

    def test_transform_money_format_when_money_is_miliar(self):
        string_money = "35.6 miliar"
        actual = transform_money_format(string_money)

        self.assertEqual(actual, "35.5")
    

    def test_transform_money_format_when_money_contains_comma(self):
        string_money = "35,5 miliar"
        actual = transform_money_format(string_money)

        self.assertEqual(actual, "35.5")

unittest.main(argv=[''], verbosity=2, exit=False)

# %% [markdown]
# ### Practice
# Lakukan Unittest seperti diatas
